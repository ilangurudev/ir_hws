# %% [markdown]
# #### CSCE 670 :: Information Storage and Retrieval :: Texas A&M University :: Spring 2018
#
#
# # Homework 0: Let's get it started
#
# - **100 points [2% of your final grade]**
# - **Due Tuesday, January 23 by 11:59pm**
#
# *Goals of this homework:* The objective of this homework is to prepare your development environment, get familiar with iPython in a Jupyter notebook, and then do some beginning exercises.
#
# *Submission instructions:* You should post your notebook to ecampus (look for the homework 0 assignment there). Please name your submission **your-uin_hw0.ipynb**, so for example, my submission would be something like **555001234_hw0.ipynb**. Your notebook should be fully executed when you submit ... so run all the cells for us so we can see the output, then submit that.

# %% [markdown]
# ## iPython, Python, and our Expectations
#
# This homework, all subsequent homeworks, and your project will use iPython in a Jupyter notebook. iPython is just an interactive shell for programming in the Python language. A few years ago, the developers created a generic interactive shell called Jupyter that supports languages beyond just Python. This can be a bit confusing, and we'll add a bit to the confusion by referring to iPython and Jupyter interchangeably in this course.
#
# With respect to Python, we do not expect you to have any prior experience. We do, however, expect you to have proficiency in some programming language (so you've seen loops, conditionals, functions, etc.) and a willingness to experiment and learn on your own. Python is a fun language and you should be able to pick up the necessary portions as we move along; however, this may require you to spend some extra cycles consulting online documentation, referring to a Python book, or scouring over StackOverflow.
#
# A few basic Python pointers:
# * http://introtopython.org
# * http://ricardoduarte.github.io/python-for-developers/
# * http://mbakker7.github.io/exploratory_computing_with_python/ [particularly the basic Python language ones]
#
# We expect your code to be well-documented with appropriate comments. We prefer meaningful variable names and function names. We also expect your code to be compact and sensible -- no super-long lines, nor dense unintelligible lines of code.
#
# In general, Python code is often run from standalone Python modules or files; for this class, we will often run Python from here within the iPython notebook.
#
# Now that you're ready, let's take a look at this iPython notebook. You'll notice that it is composed of cells. Some cells have text (like this one), while others contain code and comments. This cell is written in **Markdown** a simple text-to-HTML language. You can find a cheat sheet for Markdown here: https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet. You can toggle a cell between Markdown and code with the toggle button up there on the menu bar.
#
# The cell below contains code and can be **executed** by hitting the **Play** button on the menu bar or by hitting **shift + enter**.

# %%
# this is a comment
# you can execute this cell by hitting shift+enter
# the output will appear immediately below
print 'Hello world!'
# Out:
# Hello world!

# %% [markdown]
# Since iPython is just an interactive shell around Python, you can define functions. For example:

# %%
def cubed(x):
    """ Return the cube of a  
        value """
    return x ** 3

cubed(3)
# Out:
# 27

# %% [markdown]
# You can even access the filesystem with commands like `ls` or `pwd`:

# %%
# !pwd
# !ls
# Out:
# /home/ilangurudev/Downloads
# Anaconda2-5.0.1-Linux-x86_64.sh
# Beginner Cajon
# Beginner.zip
# CBlack
# conda-cheatsheet.pdf
# Etihad Airways 18 Jan 2018 SVCCKY_GURUDEV ILANGOVAN.pdf
# homework_0.ipynb
# intro.mp4
# mendeleydesktop-1.17.13-linux-x86_64
# mendeleydesktop-1.17.13-linux-x86_64.tar.bz2
# New-Minty
# nixnote2-2.0_amd64.deb
# Packages.gz
# ubuntu-16.04.3-desktop-amd64.iso

# %% [markdown]
# ## Getting Started with Numpy and matplotlib
#
# In this part, we're going to get familiar with two important libraries -- Numpy and matplotlib.
#
# ### Into to Numpy
# Since Python is an interpreted language, it might not seem like the best choice for data-intensive work. Luckily, almost all of our data workflow stack is built on top of Numpy, a Python library that adds support for large, multi-dimensional arrays and matrices, along with a large library of high-level mathematical functions to operate on these arrays.

# %%
import numpy as np

print "Make a 4 row x 2 column matrix of random numbers"
x = np.random.random((4, 2))
print x
print

print "Add 10 to every element"
x = x + 10
print x
print

print "Get the element at row 3, column 1"
print x[3, 1]
print

print "Get the first row"
print x[0, :]
print

print "Get the first two rows"
print x[:2]
print
# Out:
#  Make a 4 row x 2 column matrix of random numbers
# [[ 0.86392497  0.30529232]
#  [ 0.45209952  0.90193223]
#  [ 0.37592229  0.11835035]
#  [ 0.52183472  0.02521863]]
#
# Add 10 to every element
# [[ 10.86392497  10.30529232]
#  [ 10.45209952  10.90193223]
#  [ 10.37592229  10.11835035]
#  [ 10.52183472  10.02521863]]
#
# Get the element at row 3, column 1
# 10.0252186281
#
# Get the first row
# [ 10.86392497  10.30529232]
#
# Get the first two rows
# [[ 10.86392497  10.30529232]
#  [ 10.45209952  10.90193223]]

# %% [markdown]
# Now, it's your turn. Find the maximum, minimum, and mean of the array. This does not require writing a loop. In the code cell below, type `x.m<TAB>`, to find built-in operations that may help you out.

# %%
def max_min_mean(x):
  
  print x

  print "Max is ", x.max()

  print "Min is ", x.min()

  print "Mean is ", x.mean()

max_min_mean(x)
# Out:
# [[ 10.86392497  10.30529232]
#  [ 10.45209952  10.90193223]
#  [ 10.37592229  10.11835035]
#  [ 10.52183472  10.02521863]]
# Max is  10.9019322342
# Min is  10.0252186281
# Mean is  10.4455718789

# %% [markdown]
# That wasy easy! Now, let's see if you can generate 500 numbers from a uniform distribution between 0 and 10,000, inclusive. That is each random number could be 0, 1, 2, ..., 10,000 with equal chance. What is the maximum, minimum, and mean of these 500 random numbers? *Hint: take a look at np.random*

# %%
y = np.random.randint(0, 10001, 500)
max_min_mean(y)
# Out:
# [7877 5722 1481 2806 7571 5847 2389 7285 9978 4438 5446  841 6312 3731 2308
#  4210  342 7332 6109 2633 4869   64 6651 1025 2690 9031 1872 5093  668 6875
#  7373 7179 2323 3118 3580 9922 5123 6456 7275 2147 5584 2186 9819 9573 2000
#  1293  270 2017 3344 3355 2986 4215 5401 9985  989 1918 5261 2010 7849 5895
#  5495 2476 5437 1500 2785 3388 8411 2411 6930 4281 7529 1987 7368 1913 8327
#  2363 1022 3800 2396 8347 1675 2451  397  553 1522 1718 2390 1229 3000 5872
#  9070 7232 6570 8598 9868  648 7681 7120 6372 6908 9278 8813 1585 3149 4292
#  9779 4297 4175 2262 8312 6953 4768 9344 3640  156 3757 4108 6617 3093 7023
#  2219 7943 8911 9709 3155 6046 5263 2962 7219 7066 6427 4001 6862 1200 4596
#  4215 6234 7128 7497 3706 5894 3654 2398 9850 1423 8957 9531 2015 7766 2946
#  5600 4800 5886 1685 3269  626 3304 7284 9486 6368 8813  615 2054 3733 1965
#  6015 8361 6855 9632 4407 1837  696 3385  852 8709 5453 1106 6386 5707 6745
#  4234 3242 3330 8359 8216 9899 6154  673 7469 1635 5067 9246 9689 3389 6620
#  5903 2838 4525 2429 8872 9883 1262 8335  219 1223   35   16 3005 2117 5457
#  2653 2945 2800  403 7821 8275 2679 1106 5254 4197 5698 1291 4999 2939 5665
#  1492  833 1296 4981 6289  907 8398  756 7944 9302 5148 1966 4503 5145 3090
#  1396 1721  925 7195 8213 9846 3335 9037 6509 3910 8876 7071 7110 4219 5797
#  1936 9607  315 2031 5306 5645 2023  940 5978 9210 4641 4622 5150 3730 2749
#  9244 3034 3408 1733 7852 3606 4567 1979 7640 6652  265 2379 3938 7971 5363
#  6374 9983 9833  741 8359 9380 4561 3715 4081 3559 8044 4228 7036 3763 9156
#  2015 9637  890 7036 3382  791 3742 3709 1652 8321 2311 4674 9552 1558 3057
#  5146 7049 5606 5716 1582 6602 5473 6840  635 1778 8638 9651 1704 9687 9188
#  6479 1218 4845 6957 7412 3249 4073 5682 7823 8008 3927 3620 1958 8372 9828
#  1976 2351 6689 4369 2553 9949 2864  982 9404 5079 9069 6019 1164 3886 3618
#  7674 6234 3036 8289 2490  829 8337 3845 3766   98 8572 4837 2323 8803 2471
#  5516 3630 5266 7377 7059 1181 6604  686 2877 6349  126  760 9686 1132 4053
#  5145 3271  457 3928 6261 8002 6310  849 4241 2900 2853 1869 6816 3350 6534
#  3270 2566 2706 1130 9341 5586 4810 6097  835 4263 2227 7015 7028 6057  350
#  6739 1210 7621  932 7199  263 9630 5278 3933 9338 5288 4383 3436 6723 5043
#  3873 6522 4741 6531 9820 8054 1157 5601 3127 5325 9524 7299 6155 5364 3852
#   500   37 6103 3188 1848  415 6817 4573 6426 8291 8220 2243 4246 7431 6611
#  9713 5962 3172 7265 5197 8685 8229 1148 1685 4201 8742 8215 3896 9840 7994
#  4222 8048 3841 3957 3508 5991 6218 3827 5026 3880  634 6588 8308 4093 3587
#  6411 4119 7439 4382 7275]
# Max is  9985
# Min is  16
# Mean is  4859.278

# %% [markdown]
# ### Intro to matplotlib
# The most widespread Python plotting library is matplotlib. With it, you can create graphs, charts, basic maps, and other data visualizations. Later in the semester, we'll use `seaborn`, a library built on top of matplotlib that provides even more beautiful charts.
#
# Below, we provide some simple x and y coordinates that are then plotted. You should update the plot to include:
# * a label for the x-axis (call it 'X-axis')
# * a label for the y-axis (call it 'Y-axis')
# * a label for the x, y1 curve (call it 'Alice')
# * a label for the x, y2 curve (call it 'Bob')
# * a legend in the lower right corner

# %%
# this line prepares IPython for working with matplotlib
# %matplotlib inline  

import matplotlib.pyplot as plt  

x = [0, 1, 2, 3, 4]  
y1 = [10, 12, 10, 10, 12]
y2 = [8, 9, 9, 11, 12]
plt.plot(x, y1, label='Alice')
plt.plot(x, y2, label='Bob') 
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
# your code here (plus you may need to modify the previous two lines)

# %% [markdown]
# ## Python Data Structures
# Here we introduce some of the popular built-in data structures in Python: list, set and dictionary.
# #### List

# %%
x=[1, 5, 6, 3, 4, 0]
print 'Add item 7 to the list'
x.append(7)
print x
print

print 'Remove item 4 from the list'
x.remove(4)
print x
print 

print 'Insert item 3 at a position 2'
x.insert(2,3)
print x
print
# Out:
# Add item 7 to the list
# [1, 5, 6, 3, 4, 0, 7]
#
# Remove item 4 from the list
# [1, 5, 6, 3, 0, 7]
#
# Insert item 3 at a position 2
# [1, 5, 3, 6, 3, 0, 7]

# %% [markdown]
# Now, it's your turn. Sort the list and then reverse the list. In the code cell below, type x.<TAB>, to find built-in operations that may help you out.

# %%
print x

x.sort()

print x

x.reverse()

print x
# Out:
# [7, 6, 5, 3, 3, 1, 0]
# [0, 1, 3, 3, 5, 6, 7]
# [7, 6, 5, 3, 3, 1, 0]

# %% [markdown]
# #### Set
# A set is an unordered collection with no duplicate elements.

# %%
s1=set([1,2,'a','c'])
s2=set([4,5,'d','c'])
print s1
print s2
print

print 'Check if item a is in set s1'
print 'a' in s1
print

print 'return union of s1 and s2'
print s1.union(s2)
print

print 'return intersection of s1 and s2'
print s1.intersection(s2)
print
# Out:
# set(['a', 1, 2, 'c'])
# set(['c', 4, 5, 'd'])
#
# Check if item a is in set s1
# True
#
# return union of s1 and s2
# set(['a', 1, 2, 4, 5, 'c', 'd'])
#
# return intersection of s1 and s2
# set(['c'])

# %% [markdown]
# Now it's your turn to try out .add(), .remove(), .issubset() and .issuperset() built-in operations and report the results.

# %%
s1.add("z")
print s1

s1.remove("z")
print s1

print s1.issubset(s1.union(s2))

print s1.issuperset(s1.union(s2))
# Out:
# set(['a', 1, 2, 'z', 'c'])
# set(['a', 1, 2, 'c'])
# True
# False

# %% [markdown]
# #### Dictionary
# Unlike sequential data structures, which are indexed by a range of numbers, dictionaries are indexed by keys, which can be any type like strings and numbers.

# %%
dic = {'fruit': ['apple', 'orange'], 'animal': ['cat', 'dog']}
print dic
print

print 'add food with value of soup'
dic['food']=['soup']
print dic
print

print 'add value of banana into fruit'
dic['fruit'].append('banana')
print dic
# Out:
# {'fruit': ['apple', 'orange'], 'animal': ['cat', 'dog']}
#
# add food with value of soup
# {'food': ['soup'], 'fruit': ['apple', 'orange'], 'animal': ['cat', 'dog']}
#
# add value of banana into fruit
# {'food': ['soup'], 'fruit': ['apple', 'orange', 'banana'], 'animal': ['cat', 'dog']}

# %% [markdown]
# Create a dictionary where the keys are integer numbers from 0 to 10 and the corresponding values are the square of the key value.

# %%
squares = {1:1, 2:4, 3:9, 4:16, 5:25, 6:36, 7:49, 8:64, 9:81, 10:100}
print squares

squares[5]
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# 25

# %% [markdown]
# ## Getting started with File Input & Output
#
# Python can easily handle reading and writing files. As far as Python is concerned, a file is just a string (often very large!) stored on your local file system, that you can read or write, gradually or all together.
#
# ### Writing Files
#
# *open()* returns a file object, and is most commonly used with two arguments: *open(filename, mode)*.

# %%
outFile = open('sample.txt', 'w')
outFile.write('The first line\nThe second line\nThe third line\n')
outFile.close()

# %% [markdown]
# The first line creates a file object, which links Python to your computer’s file system. The first parameter in the file constructor gives the file name, *sample.txt*. The second parameter indicates how you use the file. The 'w' is short for **w**rite. If the file already existed, the old contents are destroyed.
#
# And 'a' opens the file for **a**ppending; any data written to the file is automatically added to the end. 'r+' opens the file for both reading and writing.
#
# The *close* line is essential for Python to make sure everything is really written, and to relinquish control of the file.

# %% [markdown]
# ### Methods of File Objects
#
# To read a file’s contents, call *f.read(size)*, which reads some quantity of data and returns it as a string. *size* is an optional numeric argument. When *size* is omitted or negative, the entire contents of the file will be read and returned.

# %%
outFile = open('sample.txt', 'r')
outFile.read()
# Out:
# 'The first line\nThe second line\nThe third line\n'

# %% [markdown]
# For reading lines from a file, you can loop over the file object. This is memory efficient, fast, and leads to simple code:

# %%
outFile = open('sample.txt', 'r')
for line in outFile:
    print line,
# Out:
# The first line
# The second line
# The third line

# %% [markdown]
# It is good practice to use the *with* keyword when dealing with file objects. This has the advantage that the file is properly closed after its suite finishes, even if an exception is raised on the way. It is also much shorter than writing equivalent try-finally blocks:

# %%
with open('sample.txt', 'r') as f:
    outFile = f.read()
outFile
# Out:
# 'The first line\nThe second line\nThe third line\n'

# %%
f.closed
# Out:
# True

# %%
with open('sample.txt', 'a') as f:
    f.write('The fourth line\n')

# %%
with open('sample.txt', 'r') as f:
    print f.readlines()  # readlines – reads the entire file and returns it as a list of strings
# Out:
# ['The first line\n', 'The second line\n', 'The third line\n', 'The fourth line\n']

# %% [markdown]
# ### Open a Remote File via URL
#
# Python can easily access the content of a webpage via its URL, and print out locally line-by-line without saving a local copy of the file.

# %%
import urllib2  # the lib that handles the url stuff

url = "http://courses.cse.tamu.edu/caverlee/csce670/"


u = urllib2.urlopen(url)
u = u.read()
# your code here: open the url. Hint: take a look at urllib2.urlopen
# your code here: now print out each line

# %% [markdown]
# ## Counting Word Frequency
#
# One of the most fundamental tasks in information retrieval is to count the frequency of each word in a document.
#
# In the following example, we start with a string and split it into a list. We then create an (initially empty) list called *wordfreq*, go through each word in the *wordlist*, and count the number of times that word appears in the whole list. We then add each word’s count to our wordfreq list. Using the *zip* operation, we are able to match the first word of the word list with the first number in the frequency list, the second word and second frequency, and so on. We end up with a list of word and frequency pairs. The *str* function converts any object to a string so that it can be printed.

# %%
wordstring = 'it was the best of times it was the worst of times '
wordstring += 'it was the age of wisdom it was the age of foolishness'

wordlist = wordstring.split()

wordfreq = []
for w in wordlist:
    wordfreq.append(wordlist.count(w))

print("String\n" + wordstring +"\n")
print("List\n" + str(wordlist) + "\n")
print("Frequencies\n" + str(wordfreq) + "\n")
print("Pairs\n" + str(dict(zip(wordlist, wordfreq))))
# Out:
# String
# it was the best of times it was the worst of times it was the age of wisdom it was the age of foolishness
#
# List
# ['it', 'was', 'the', 'best', 'of', 'times', 'it', 'was', 'the', 'worst', 'of', 'times', 'it', 'was', 'the', 'age', 'of', 'wisdom', 'it', 'was', 'the', 'age', 'of', 'foolishness']
#
# Frequencies
# [4, 4, 4, 1, 4, 2, 4, 4, 4, 1, 4, 2, 4, 4, 4, 2, 4, 1, 4, 4, 4, 2, 4, 1]
#
# Pairs
# {'of': 4, 'age': 2, 'it': 4, 'foolishness': 1, 'times': 2, 'worst': 1, 'the': 4, 'wisdom': 1, 'was': 4, 'best': 1}

# %% [markdown]
# Now, your job is to open up the url we mentioned a few cells above. Then output the word-frequency pairs in that url, sorted in order of descending frequency. In the case of ours Dickens example here, the output would look something like: [('of', 4), ('it', 4), ('the', 4), ('was', 4), ('age', 2), ('times', 2), ('foolishness', 1), ('worst', 1), ('wisdom', 1), ('best', 1)].
#
# Your job is to output a the word-frequency pairs for the url.

# %%
wordlist = u.split()

wordfreq = []
for w in wordlist:
    wordfreq.append(wordlist.count(w))


dict1 = dict(zip(wordlist, wordfreq))
for w in sorted(dict1, key=dict1.get, reverse=True):
  print w,":",dict1[w]


dict1
# Out:
# {'"The': 1,
#  '"ada">Americans': 1,
#  '"comm">Communication</a></H3>': 1,
#  '"grading">Grading</a></H3>': 1,
#  '"honor">Academic': 1,
#  '"prereq">Prerequisites</a></H3>': 1,
#  '"summary">Course': 1,
#  '"textbooks">Textbooks</a></H3>': 1,
#  "''An": 1,
#  '(10%)</b>.': 1,
#  '(20%)</b>.': 1,
#  '(25%)</b>.': 1,
#  '(40%)</b>.': 1,
#  '(5': 1,
#  '(5%)</b>.': 1,
#  '(ADA)': 2,
#  '(Hey,': 1,
#  '(Of': 1,
#  '(and': 1,
#  '(but': 1,
#  '(e.g.,': 1,
#  '(every': 1,
#  '(front': 1,
#  '--': 1,
#  '0-59.': 1,
#  '10': 3,
#  '11"': 1,
#  '11:59pm': 1,
#  '18.': 1,
#  '2-4pm': 2,
#  '20%': 1,
#  '2005</dt>': 1,
#  '2008.': 1,
#  '2010.': 2,
#  '2018': 1,
#  '2018</TITLE>': 1,
#  '24-hour': 1,
#  '3': 2,
#  '3).': 1,
#  '403': 1,
#  '408D': 1,
#  '5': 1,
#  '60-69,': 1,
#  '670': 2,
#  '7,': 1,
#  '70-79,': 1,
#  '8.5"': 1,
#  '80-89,': 1,
#  '9-11am': 1,
#  '90-100,': 1,
#  '979-845-1637.': 1,
#  '9:35-10:50am': 1,
#  '::': 5,
#  '</h1>': 1,
#  '</head>': 1,
#  '</ul>': 3,
#  '<BR>': 2,
#  '<H3><A': 7,
#  '<P>': 6,
#  '<TITLE>CSCE': 1,
#  '<a': 11,
#  '<b>5': 1,
#  '<b>Discussion': 1,
#  '<b>Exams': 1,
#  '<b>Homework': 1,
#  '<b>In-Class': 1,
#  '<b>in': 1,
#  '<b>post': 1,
#  '<b>two</b>': 1,
#  '<b>up': 1,
#  '<body': 1,
#  '<br/>': 1,
#  '<dt>': 7,
#  '<dt><br/>': 1,
#  '<dt>Tues/Thurs': 1,
#  '<h1>': 1,
#  '<hr>': 7,
#  '<html><head>': 1,
#  '<i><a': 4,
#  '<i>Foundations': 1,
#  '<i>Managing': 1,
#  '<i>Modern': 1,
#  '<i>Search': 1,
#  '<li>': 8,
#  '<li>Define': 1,
#  '<li>Design,': 1,
#  '<li>Identify': 1,
#  '<p>': 7,
#  '<p><a': 1,
#  '<p><b>It': 1,
#  '<p><b>Project': 1,
#  '<p><b>Regrade': 1,
#  '<p><i>Homework': 3,
#  '<p>All': 1,
#  '<ul>': 3,
#  '=': 7,
#  'A&M': 1,
#  'A&amp;M': 1,
#  'A:': 1,
#  'AGGIE': 1,
#  'About': 1,
#  'Act': 2,
#  'Aggie': 2,
#  'All': 2,
#  'Americans': 1,
#  'Among': 1,
#  'Anand': 1,
#  'Android': 1,
#  'April': 1,
#  'As': 1,
#  'Available': 1,
#  'B:': 1,
#  'Baeza-Yates': 1,
#  'Beatles").': 1,
#  'Bell.': 1,
#  'Bob': 1,
#  'Both': 1,
#  'By': 1,
#  'C:': 1,
#  'CODE:': 1,
#  'CSCE': 1,
#  'Cambridge': 2,
#  'Caverlee</a>,': 1,
#  'Central': 1,
#  'Christopher': 1,
#  'Clarification</i>:': 1,
#  'Code,': 1,
#  'Collaboration': 1,
#  'Connected': 1,
#  'Creek': 1,
#  'Croft,': 1,
#  'Crowds,': 1,
#  'D.': 1,
#  'D:': 1,
#  'DITP:': 1,
#  'Datasets</a></i>,': 1,
#  'David': 1,
#  'Days</i>:': 1,
#  'Department': 1,
#  'Disabilities': 2,
#  'Disability': 2,
#  'Dyer,': 1,
#  'ETB': 1,
#  'Easley': 1,
#  'Engineering</a>': 1,
#  'Engines:': 1,
#  'F': 1,
#  'F:': 1,
#  'For': 6,
#  'Gigabytes</i>,': 1,
#  'HONOR': 1,
#  'HRBB': 1,
#  'Hence': 1,
#  'Highly': 1,
#  'Hinrich': 1,
#  'Honor': 4,
#  'Hours:': 2,
#  'However,': 3,
#  'I': 2,
#  'IIR:': 1,
#  'If': 5,
#  'Ignorance': 1,
#  'In': 1,
#  'Information': 5,
#  'Instructor:': 1,
#  'Integrity': 1,
#  'Jeff': 1,
#  'Jon': 1,
#  'Jure': 1,
#  'Kaghazgaran,': 1,
#  'Keeping': 1,
#  'Kleinberg,': 1,
#  'Language': 1,
#  'Late': 1,
#  'Leskovec,': 1,
#  'Lin': 1,
#  'MMD:': 1,
#  'Manning': 1,
#  'Manning,': 1,
#  'MapReduce</i></a>,': 1,
#  'Markets:': 1,
#  'Massive': 1,
#  'Metzler,': 1,
#  'Moffat,': 1,
#  'Monday': 1,
#  'Moss</a>': 1,
#  'NAME': 7,
#  'NCM:': 1,
#  'Natural': 1,
#  'No': 1,
#  'Note': 2,
#  'Of': 1,
#  'Office': 2,
#  'Once': 1,
#  'Over': 1,
#  'PageRank.': 1,
#  'Parisa': 1,
#  'Piazza,': 1,
#  'Piazza.': 1,
#  'Plagiarism': 1,
#  'Policy': 1,
#  'Policy</b>:': 1,
#  'Policy</i>:': 1,
#  'Posts': 1,
#  'Prabhakar': 1,
#  'Practice</i>,': 1,
#  'Press.': 2,
#  'Press</a>,': 1,
#  'Processing': 1,
#  'Processing</i>,': 1,
#  'Python': 1,
#  'Python;': 1,
#  'Quick': 1,
#  'Quizzes': 1,
#  'Raghavan,': 1,
#  'Rajarman,': 1,
#  'Reasoning': 1,
#  'Retrieval': 3,
#  'Retrieval</a></i>,': 1,
#  'Retrieval</i>,': 1,
#  'Ribeiro-Neto.': 1,
#  'Schedule</a>': 1,
#  'Schutze,': 1,
#  'Schutze.': 1,
#  'Science': 1,
#  'Services': 2,
#  'Services,': 1,
#  'Spring': 2,
#  'Statement</a></H3>': 1,
#  'Statements</a></H3>': 1,
#  'Statistical': 1,
#  'Storage': 2,
#  'Strohman.': 1,
#  'Student': 1,
#  'Students': 2,
#  'Summary</a></H3>': 1,
#  'System.': 3,
#  'TA.': 1,
#  'TA:': 1,
#  'TAMU': 1,
#  'Texas': 1,
#  'Text': 1,
#  'The': 5,
#  'These': 1,
#  'Thursday': 1,
#  'To': 1,
#  'Towards': 1,
#  'Ullman.': 1,
#  'University': 3,
#  'University,': 1,
#  'University</a>': 1,
#  'Upon': 1,
#  'We': 7,
#  'Web': 1,
#  'Web-based': 1,
#  'Wednesday': 2,
#  'White': 1,
#  'Witten,': 1,
#  'World</i></a>,': 1,
#  'You': 3,
#  'Your': 2,
#  'a': 23,
#  'abacuses': 1,
#  'able': 2,
#  'about': 2,
#  'academic': 1,
#  'accept': 2,
#  'accepting': 1,
#  'accommodation': 1,
#  'accommodation,': 1,
#  'across': 1,
#  'actual': 2,
#  'additional': 2,
#  'admission': 1,
#  'advanced': 1,
#  'adversarial': 1,
#  'afterwards,': 1,
#  'aid': 1,
#  'algorithms': 4,
#  'algorithms,': 1,
#  'alink=blue>': 1,
#  'all': 3,
#  'allowed.</i>': 1,
#  'alone': 1,
#  'alone.': 1,
#  'also': 1,
#  'an': 5,
#  'and': 50,
#  'another': 2,
#  'answer': 2,
#  'anti-discrimination': 1,
#  'any': 4,
#  'anyone': 1,
#  'apply': 1,
#  'approaches': 1,
#  'approaches,': 1,
#  'appropriate': 1,
#  'are': 8,
#  'as': 6,
#  'aspects': 1,
#  'assignment': 4,
#  'assignment,': 1,
#  'assignments': 3,
#  'assignments,': 2,
#  'assignments.': 2,
#  'assumes': 1,
#  'at': 7,
#  'attendance': 1,
#  'automatic': 1,
#  'back).': 1,
#  'basic': 3,
#  'be': 14,
#  'been': 2,
#  'before': 1,
#  'before,': 1,
#  'before.': 1,
#  'being': 1,
#  'believe': 2,
#  'bgcolor=white': 1,
#  'book,': 1,
#  'booksellers.': 1,
#  'boolean,': 1,
#  'both': 1,
#  'brief': 1,
#  'bring': 1,
#  'building': 1,
#  'but': 3,
#  'by': 10,
#  'calculators,': 1,
#  'call': 1,
#  'campus': 1,
#  'can': 5,
#  'cannot': 1,
#  'categorization,': 1,
#  'categorization.': 1,
#  'chance': 1,
#  'chat': 1,
#  'cheat,': 1,
#  'check': 2,
#  'choosing': 1,
#  'circumvent': 1,
#  'civil': 1,
#  'clarification,': 1,
#  'clarify,': 1,
#  'class': 6,
#  'class,': 2,
#  'classmates.': 1,
#  'closed': 1,
#  'clustering': 2,
#  'collaboration': 1,
#  'collaborative': 1,
#  'come': 1,
#  'commitment': 2,
#  'communication': 1,
#  'community': 1,
#  'complete': 1,
#  'complex': 1,
#  'components,': 1,
#  'comprehensive': 1,
#  'concepts': 1,
#  'contact': 2,
#  'contain': 1,
#  'continue': 1,
#  'copied': 1,
#  'core': 2,
#  'could': 1,
#  'count': 2,
#  'course': 6,
#  'course,': 2,
#  'course.': 2,
#  'cover': 1,
#  'crawling,': 1,
#  'critically': 1,
#  'currently': 1,
#  'data': 1,
#  'date.': 1,
#  'day': 2,
#  'day).': 1,
#  'days': 1,
#  'days,': 1,
#  'days</b>': 1,
#  'deem': 1,
#  'describing': 1,
#  'design': 1,
#  'design,': 1,
#  'detailed': 1,
#  'develop': 1,
#  'direct': 1,
#  'directions,': 1,
#  'directly': 1,
#  'disabilities': 1,
#  'disabilities.': 2,
#  'disability': 1,
#  'discuss': 2,
#  'discussed': 1,
#  'discussion': 1,
#  'discussions': 2,
#  'do': 4,
#  "do.''": 1,
#  'document': 2,
#  'does': 2,
#  'done': 1,
#  'due': 1,
#  'during': 1,
#  'each': 2,
#  'each)': 1,
#  'earning': 1,
#  'efficient': 1,
#  'either': 1,
#  'else.': 1,
#  'encourage': 1,
#  'end': 1,
#  'engage': 1,
#  'engaged': 1,
#  'entire': 1,
#  'environment': 1,
#  'error': 1,
#  'error.': 1,
#  'errors': 1,
#  'etc.': 1,
#  'evaluate': 1,
#  'examinations,': 1,
#  'examine': 1,
#  'exams': 1,
#  'exams,': 1,
#  'exclude': 1,
#  'exhaust': 1,
#  'expect': 5,
#  'expectations': 1,
#  'expected': 1,
#  'explain': 1,
#  'explicitly': 1,
#  'exposed': 1,
#  'exposure': 1,
#  'facilitating': 1,
#  'factorization,': 1,
#  'fashion.': 1,
#  'features': 1,
#  'federal': 1,
#  'feedback,': 1,
#  'feel': 3,
#  'filtering,': 1,
#  'final': 1,
#  'find': 2,
#  'fine': 1,
#  'first': 3,
#  'follow': 1,
#  'follows:': 1,
#  'for': 7,
#  'found': 1,
#  'four': 1,
#  'free': 1,
#  'from': 2,
#  'from:': 1,
#  'fully': 1,
#  'functional': 1,
#  'general': 3,
#  'given': 1,
#  'grade,': 1,
#  'grade.': 1,
#  'grade.)': 1,
#  'graded': 1,
#  'grading': 2,
#  'grading,': 1,
#  'group': 1,
#  'groups': 1,
#  'guaranteed': 1,
#  'had': 1,
#  'has': 1,
#  'have': 13,
#  'help': 2,
#  'helpful,': 1,
#  "here's": 1,
#  'highlight': 1,
#  'hint:': 1,
#  'homework': 10,
#  'however,': 1,
#  'href="http://aggiehonor.tamu.edu">http://aggiehonor.tamu.edu</a>': 1,
#  'href="http://disability.tamu.edu">http://disability.tamu.edu</a>.': 1,
#  'href="http://faculty.cse.tamu.edu/caverlee/">James': 1,
#  'href="http://lintool.github.io/MapReduceAlgorithms/ed1n.html">Data-Intensive': 1,
#  'href="http://nlp.stanford.edu/IR-book/information-retrieval-book.html">Introduction': 1,
#  'href="http://theory.stanford.edu/~aiken/moss/">Stanford': 1,
#  'href="http://www.amazon.com/Introduction-Information-Retrieval-Christopher-Manning/dp/0521865719">Amazon</a>,': 1,
#  'href="http://www.cambridge.org/us/catalogue/catalogue.asp?isbn=9780521865715">Cambridge': 1,
#  'href="http://www.cs.cornell.edu/home/kleinber/networks%2Dbook/">Networks,': 1,
#  'href="http://www.cse.tamu.edu">Computer': 1,
#  'href="http://www.mmds.org">Mining': 1,
#  'href="http://www.tamu.edu">Texas': 1,
#  'href="https://piazza.com/tamu/spring2018/csce670">Piazza</a>.': 1,
#  'href="https://piazza.com/tamu/spring2018/csce670/home">Piazza</a>.': 1,
#  'href="project.html">Project</a>': 1,
#  'href="schedule.html">Course': 1,
#  'iPads,': 1,
#  'iPhones,': 1,
#  'if': 1,
#  'immediately': 1,
#  'implement,': 1,
#  'implementation': 1,
#  'important': 3,
#  'in': 18,
#  'in-class': 2,
#  'include': 1,
#  'including': 5,
#  'independently.': 1,
#  'indexing,': 3,
#  'indivisible': 1,
#  'inform': 1,
#  'information': 5,
#  'information,': 1,
#  'interesting,': 1,
#  'is': 15,
#  'issue': 1,
#  'it': 4,
#  'just': 2,
#  'key': 1,
#  'large': 1,
#  'late': 4,
#  'late</b>': 1,
#  'learn': 1,
#  'learning': 2,
#  'learning,': 2,
#  'least': 1,
#  'legislation': 1,
#  'libraries': 1,
#  'lie,': 1,
#  'like': 3,
#  'limited': 1,
#  'link-based': 1,
#  'link=blue': 1,
#  'located': 1,
#  'made': 1,
#  'make': 2,
#  'management.': 1,
#  'material': 1,
#  'material,': 1,
#  'matrix': 1,
#  'may': 6,
#  'me': 2,
#  'meaning': 1,
#  'meetings': 1,
#  'member': 2,
#  'memorize': 1,
#  'minutes': 1,
#  'miss': 1,
#  'missed': 1,
#  'mix': 1,
#  'models': 1,
#  'models,': 1,
#  'modern': 1,
#  'most': 1,
#  'must': 6,
#  'needs': 1,
#  'negative': 1,
#  'new': 1,
#  'no': 3,
#  'none': 1,
#  'not': 7,
#  'note': 1,
#  'notes': 1,
#  'of': 27,
#  'often': 2,
#  'okay': 1,
#  'on': 11,
#  'on.': 2,
#  'online': 1,
#  'only,': 1,
#  'opportunities': 1,
#  'optional': 1,
#  'or': 10,
#  'other': 6,
#  'others.': 1,
#  'our': 3,
#  'overall': 1,
#  'own.': 1,
#  'paper': 1,
#  'papers': 1,
#  'papers,': 1,
#  'participate': 1,
#  'participation': 2,
#  'particular': 1,
#  'pass.': 1,
#  'persons': 1,
#  'philosophy': 1,
#  'phones/tablets,': 1,
#  'pieces': 1,
#  'plagiarism': 1,
#  'plagiarism.': 1,
#  'plan': 1,
#  'please': 2,
#  'pointed': 1,
#  'policy': 1,
#  'portion': 1,
#  'post': 4,
#  'posts': 1,
#  'previous': 1,
#  'primary': 1,
#  'probabilistic': 1,
#  'probability,': 1,
#  'problem': 4,
#  'problem,': 1,
#  'problems': 3,
#  'process),': 1,
#  'processes': 1,
#  'programming': 2,
#  'programs': 1,
#  'project,': 1,
#  'protection': 1,
#  'provided': 1,
#  'provides': 2,
#  'punished': 1,
#  'purposes': 1,
#  'question': 1,
#  'question,': 1,
#  'questions,': 1,
#  'quick': 2,
#  'quiz': 1,
#  'quizzes': 1,
#  'quizzes,': 1,
#  'ranking': 1,
#  'rapidly.': 1,
#  'read': 1,
#  'reading': 1,
#  'readings': 3,
#  'readings;': 1,
#  'reasonable': 2,
#  'recent': 1,
#  'recommender': 2,
#  'regrade.': 1,
#  'related': 1,
#  'relevance': 1,
#  'relevant': 4,
#  'repercussions.': 1,
#  'reported': 1,
#  'required': 1,
#  'required:': 1,
#  'requirements': 1,
#  'requires': 1,
#  'requiring': 1,
#  'research': 2,
#  'reserve': 1,
#  'resources': 1,
#  'responsibility': 1,
#  'resubmit': 1,
#  'results': 1,
#  'retrieval': 2,
#  'retrieval,': 3,
#  'right': 1,
#  'rights': 1,
#  'rule': 1,
#  'rules': 2,
#  'salient': 1,
#  'scale': 1,
#  'search': 3,
#  'search,': 1,
#  'section': 1,
#  'selections': 1,
#  'semester': 1,
#  'semester,': 1,
#  'semester.': 2,
#  'sets.': 1,
#  'several': 2,
#  'severely,': 1,
#  'share': 2,
#  'should': 5,
#  'significant': 2,
#  'significant,': 1,
#  'single': 1,
#  'so': 8,
#  'social': 1,
#  'software': 1,
#  'solely': 1,
#  'solution': 3,
#  'solutions': 1,
#  'solutions)': 1,
#  'some': 3,
#  "someone's": 1,
#  'space': 1,
#  'speed': 1,
#  'spread': 1,
#  'standard': 1,
#  'state': 1,
#  'statement': 1,
#  'statistics,': 1,
#  'statute': 1,
#  'stay': 1,
#  'steal': 1,
#  'storage': 1,
#  'structures.': 1,
#  'student': 4,
#  'students': 2,
#  'students,': 1,
#  'study': 2,
#  'submission': 1,
#  'submissions': 1,
#  'submissions.': 1,
#  'submitted': 3,
#  'success': 1,
#  'such': 1,
#  'system': 1,
#  'system,': 1,
#  'systems,': 2,
#  'systems.': 1,
#  'talk': 2,
#  'team': 1,
#  'teams': 1,
#  'techniques': 1,
#  'text': 3,
#  'text-based': 1,
#  'text=black': 1,
#  'textbook': 1,
#  'textbooks': 1,
#  'that': 18,
#  'the': 55,
#  'their': 2,
#  'them': 2,
#  'theory,': 1,
#  'there': 1,
#  'thereby': 1,
#  'these': 3,
#  'things,': 1,
#  'this': 3,
#  'this,': 1,
#  'those': 2,
#  'though': 1,
#  'three': 1,
#  'time': 2,
#  'timely': 1,
#  'times;': 1,
#  'to': 45,
#  'to:': 1,
#  'together.</b>': 1,
#  'tolerate': 1,
#  'top': 1,
#  'topics': 2,
#  'topics,': 1,
#  'total': 1,
#  'toward': 1,
#  'treat': 1,
#  'two': 1,
#  'two</b>': 1,
#  'typically': 1,
#  'underlying': 1,
#  'unit.': 1,
#  'up': 4,
#  'uphold': 1,
#  'us': 1,
#  'use': 2,
#  'vector': 1,
#  'via': 1,
#  'visit': 1,
#  'visit:': 1,
#  'vlink=blue': 1,
#  'way</b>.': 1,
#  'we': 16,
#  "we'll": 1,
#  'web': 2,
#  'week': 1,
#  'welcome': 1,
#  'well': 2,
#  'west': 1,
#  'what': 1,
#  'who': 2,
#  'will': 16,
#  'with': 12,
#  'with.': 1,
#  'without': 1,
#  'work': 5,
#  'work.': 1,
#  'worth': 1,
#  'write': 1,
#  'writing': 1,
#  'written': 3,
#  'you': 35,
#  'your': 13,
#  'yours': 2}
